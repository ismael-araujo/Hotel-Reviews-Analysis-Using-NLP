# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Pandas Settings
pd.set_option('display.max_columns', 10000)
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv('../csv/Hotel_Review_Spell_Checked.csv', index_col=0)

# %%
df.drop(columns=['Unnamed: 0.1'], inplace=True)

# %%
vader = SentimentIntensityAnalyzer()

# %%
polarity = lambda x: vader.polarity_scores(x)

# %%
df['Polarity'] = df['Spell_Checked'].apply(polarity)

# %%
df.head(2)
# Out:
#                           Hotel_Name Negative_Review  \
# 0  St James Court A Taj Hotel London     No Negative
# 1             H10 Metropolitan 4 Sup        Nothing
#
#                                     Positive_Review  Reviewer_Score  \
# 0                         the location was perfect              9.6
# 1   Everything was top notch staff were impeccable             10.0
#
#                                        Reviews_Clean  Score  \
# 0              no negative the location was perfect       1
# 1   nothing  everything was top notch staff were ...      1
#
#                                        Spell_Checked  \
# 0              no negative the location was perfect
# 1   nothing  everything was top notch staff were ...
#
#                                             Polarity
# 0  {'neg': 0.0, 'neu': 0.374, 'pos': 0.626, 'comp...
# 1  {'neg': 0.185, 'neu': 0.815, 'pos': 0.0, 'comp...

# %%
df = pd.concat([df.drop(['Hotel_Name','Reviews_Clean'], axis=1), df['Polarity'].apply(pd.Series)], axis=1)

# %%
df.head(10)
# Out:
#                                      Negative_Review  \
# 0                                        No Negative
# 1                                           Nothing
# 2                               Prices are elevated
# 3                                        No Negative
# 4   There was nothing that I could say I was not ...
# 5   there are currently construction works outsid...
# 6   No face washers in rooms Tissue box not refil...
# 7                                        No Negative
# 8   Hotel is situated in a very loud street and e...
# 9   The decor we found it too minimalist for our ...
#
#                                      Positive_Review  Reviewer_Score  Score  \
# 0                          the location was perfect              9.6      1
# 1    Everything was top notch staff were impeccable             10.0      1
# 2   Location was perfect if you want to go to the...             9.2      1
# 3   Great location right in the inner stadt close...             9.6      1
# 4   Lovely room very comfortable cleanliness exce...            10.0      1
# 5                      the location was very central             8.3      1
# 6                                  Rooms were clean              7.9      1
# 7                             Great staff comfy beds            10.0      1
# 8   Excellent location staff very friendly and he...             9.2      1
# 9            Loved the bed and the size of the room              9.2      1
#
#                                        Spell_Checked  \
# 0              no negative the location was perfect
# 1   nothing  everything was top notch staff were ...
# 2   prices are elevated  location was perfect if ...
# 3  no negative great location right in the inner ...
# 4   there was nothing that i could say i was not ...
# 5   there are currently construction works outsid...
# 6   no face rashers in rooms tissue box not fille...
# 7                  no negative great staff come beds
# 8   hotel is situated in a very loud street and e...
# 9   the door we found it too minimalist for our t...
#
#                                             Polarity    neg    neu    pos  \
# 0  {'neg': 0.0, 'neu': 0.374, 'pos': 0.626, 'comp...  0.000  0.374  0.626
# 1  {'neg': 0.185, 'neu': 0.815, 'pos': 0.0, 'comp...  0.185  0.815  0.000
# 2  {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'comp...  0.000  0.688  0.312
# 3  {'neg': 0.078, 'neu': 0.638, 'pos': 0.284, 'co...  0.078  0.638  0.284
# 4  {'neg': 0.118, 'neu': 0.487, 'pos': 0.394, 'co...  0.118  0.487  0.394
# 5  {'neg': 0.122, 'neu': 0.878, 'pos': 0.0, 'comp...  0.122  0.878  0.000
# 6  {'neg': 0.245, 'neu': 0.562, 'pos': 0.194, 'co...  0.245  0.562  0.194
# 7  {'neg': 0.32, 'neu': 0.389, 'pos': 0.291, 'com...  0.320  0.389  0.291
# 8  {'neg': 0.068, 'neu': 0.768, 'pos': 0.164, 'co...  0.068  0.768  0.164
# 9  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'comp...  0.000  0.822  0.178
#
#    compound
# 0    0.7716
# 1   -0.1511
# 2    0.6124
# 3    0.8273
# 4    0.9346
# 5   -0.3612
# 6   -0.0222
# 7   -0.0762
# 8    0.8253
# 9    0.5994

# %%
no_negative = df[df['Negative_Review'] == 'No Negative']
no_positive = df[df['Positive_Review'] == 'No Positive']

# %%
no_negative.groupby('Score').mean()
# Out:
#        Reviewer_Score       neg       neu       pos  compound
# Score
# 0             4.57500  0.089007  0.583637  0.327327  0.311574
# 1             9.38974  0.061900  0.510314  0.427782  0.720115

# %%
no_negative.groupby('Score').describe()
# Out:
#       Reviewer_Score                                                   neg  \
#                count     mean       std  min  25%  50%   75%   max   count
# Score
# 0              284.0  4.57500  1.067629  2.5  3.8  5.0   5.4   5.8   284.0
# 1             3002.0  9.38974  0.772413  6.3  9.2  9.6  10.0  10.0  3002.0
#
#                                                             neu            \
#            mean       std  min  25%  50%     75%    max   count      mean
# Score
# 0      0.089007  0.119254  0.0  0.0  0.0  0.1525  0.470   284.0  0.583637
# 1      0.061900  0.097550  0.0  0.0  0.0  0.1040  0.462  3002.0  0.510314
#
#                                                        pos            \
#             std    min    25%    50%    75%    max   count      mean
# Score
# 0      0.191975  0.143  0.403  0.603  0.751  0.927   284.0  0.327327
# 1      0.158532  0.074  0.395  0.509  0.629  0.921  3002.0  0.427782
#
#                                                       compound            \
#             std    min      25%     50%    75%    max    count      mean
# Score
# 0      0.197474  0.022  0.14975  0.2805  0.500  0.830    284.0  0.311574
# 1      0.143089  0.050  0.32200  0.4280  0.531  0.809   3002.0  0.720115
#
#
#             std     min     25%      50%     75%     max
# Score
# 0      0.431542 -0.9453  0.0951  0.45850  0.5975  0.9740
# 1      0.283328 -0.8112  0.5994  0.82435  0.9231  0.9975

# %%
no_positive.groupby('Score').mean()
# Out:
#        Reviewer_Score       neg       neu       pos  compound
# Score
# 0            4.587668  0.184590  0.676807  0.138599 -0.224394
# 1            7.988995  0.169912  0.623845  0.206236  0.014253

# %%
no_positive.groupby('Score').describe()
# Out:
#       Reviewer_Score                                                   neg  \
#                count      mean       std  min  25%  50%  75%   max   count
# Score
# 0             2376.0  4.587668  0.981704  2.5  3.8  4.6  5.4   5.8  2376.0
# 1              627.0  7.988995  1.113534  6.0  7.1  7.9  8.8  10.0   627.0
#
#                                                                 neu            \
#            mean       std  min    25%    50%     75%    max   count      mean
# Score
# 0      0.184590  0.144827  0.0  0.089  0.158  0.2580  0.838  2376.0  0.676807
# 1      0.169912  0.160776  0.0  0.000  0.147  0.2535  0.837   627.0  0.623845
#
#                                                       pos                      \
#             std  min    25%    50%     75%    max   count      mean       std
# Score
# 0      0.174902  0.0  0.584  0.717  0.8070  0.948  2376.0  0.138599  0.165003
# 1      0.183416  0.0  0.526  0.660  0.7665  0.947   627.0  0.206236  0.203347
#
#                                      compound                              \
#        min  25%    50%    75%    max    count      mean       std     min
# Score
# 0      0.0  0.0  0.087  0.191  0.872   2376.0 -0.224394  0.561668 -0.9890
# 1      0.0  0.0  0.154  0.340  0.906    627.0  0.014253  0.550464 -0.9252
#
#
#            25%     50%     75%     max
# Score
# 0     -0.72165 -0.4449  0.3313  0.9960
# 1     -0.44490  0.1037  0.5574  0.9836

# %%
no_pos_neg = df[(df['Positive_Review'] == 'No Positive') & (df['Negative_Review'] == 'No Negative')]

# %%
no_pos_neg.shape
# Out:
# (5, 10)
