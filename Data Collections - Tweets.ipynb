# %%
import twint

# %%
# Configure
c = twint.Config()
c.Search = "hotel costes paris"
c.Output = "none.csv"
c.Lang = "en"
c.Translate = True
c.Limit = 100

# Run
twint.run.Search(c)
# Out:
# 293970023620411393 2013-01-23 01:34:49 -0500 <zaldabbous> Photo: lobekardashians: kim leaving Hotel Costes in Paris  http://t.co/It68mCj
# 293969746343366656 2013-01-23 01:33:43 -0500 <zaldabbous> Photo: 1/22: Leaving Hotel Costes in Paris, France.  http://t.co/1H16NDt
# 293885758685708289 2013-01-22 20:00:00 -0500 <Kardashian_uy> Kim leaving Hotel Costes in Paris // Kim saliendo del Hotel Costes en París  http://t.co/oX4voU7Z
# 293839551372353536 2013-01-22 16:56:23 -0500 <Toyoo4real> Kim and Joyce leaving Hotel Costes in Paris.  http://t.co/UNqAxZci
# 293836670825009152 2013-01-22 16:44:56 -0500 <SweetKimKardash> @KimKardashian est a l'hôtel costes a paris ;D
# 293823384033325057 2013-01-22 15:52:08 -0500 <KardashianWord> kim leaving Hotel Costes in Paris  http://t.co/zuuCFpZC
# 293821713433653249 2013-01-22 15:45:30 -0500 <socialxsearch> Kim Kardashian covers her growing baby bump with a black flowing coat whilst leaving Hotel Costes in Paris ,  http://t.co/F5bt09PZ
# ...
